_Ysj88W9GANK7IXwUJ2WOXSVBjnZjyKDUsYk4wEPJLialRlbxWZPoU77ekv-kofWGtnNh5_XqogLlNwejg7fW1Er61X6snfMgjqLSDkdi_zTdioyGqTg9jojspC2o30R_mBouhl6WmV8rmfwT26ebiwtgZoqvQzDGthe5xfsAnY28Vb_hKhSuxwMA7xOexp0nc8G-xPHh716bFJF40rLS1B09SUxF0CXhjAKnlnJUoQKiCCAhLheI2LqFvysdGoQuoMuaKyjt199DASk8eLt8O5lkm87j0czfX3C9zeWVhQSepn1OlxmMMcXkyjl8ZGNnghMvuLCy8XsGZ5QYyQdcmbY8xoOsPfXheTbVGjNi0ExgUY_kWL9JgFIlTCBtm3mlv16RlI7UfdrwraCFQ7KP-udYXo_TDrVCDjqFmXXnwzTHYoAyKvwZ2tJJ745b6-E5m843ZLYKwuxaADg-MZmd00qM5F-XEsKxrXgQ8kkuscF0akP3pPPNMncPqt1FZxoFfgKVZsgokNXocJFKsrAcHWPzNPxYkocJJ1isiuWBXoG43Y0IUEACTqCJFGJWmlKeEOHIu0WEzR9HUdZV-uebQQQQaau0JyHHU45Klmrw5o5yhhRMCJjfH_qMCAHH0FNMwGRbI7LsvPM6acNwzC3EouQGWXssEzRXqkNWQBmPKcxKBtFzJbq-nOfrM1syr0QolHgEfABmPcDydD0cukuUMX78qIFAycR21HsB1RXlvgMJxHK6rOsOZn2T20oWhUwq3vfCcfzRWK7HdfNkH3oHZJgyzYQN2srOiIUiWjqHMEWEki9yYD3guShjOAZ0fGFUwhW36b39aroDs0YAZvDRRmu0I9T0jBGo_rtsz55MUY6F4G-T-XBZLj2-buvuvnjyOFy3Ug.s5R-q5kRSZkS0I6FUFYx6A"
model = whisper.load_model("base")
model.device
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 64.4MiB/s]
# device(type='cpu')

# %%
def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    result_text = result.text

    # Pass the generated text to ChatGPT
    chatgpt_api = ChatGPT(secret_token)
    resp = chatgpt_api.send_message(result_text)
    out_result = resp['message']

    # Text to Speech
    gtts_obj = gTTS(text = out_result, lang="en", tld="ca", slow=False)
    gtts_obj.save("/content/gtts.wav")

    return [result_text, out_result, "/content/gtts.wav"]

# %%
output_user = gr.Textbox(label="Pertanyaan lu:")
output_AI = gr.Textbox(label="Jawaban gw:")
output_AI_audio = gr.Audio(label="jawaban gw, tapi versi suara:")


gr.Interface(
    title = 'Kasi gw pertanyaan sulit cok', 
    fn = transcribe, 
    inputs=[
        gr.inputs.Audio(source="microphone", label="record suara lu cok", type="filepath")
    ],

    outputs=[
        output_user, output_AI, output_AI_audio
    ],
    live=True, share=True).launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %%
# !pip install -q gradio
# !pip install -q git+https://github.com/huggingface/transformers.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import gradio as gr
import tensorflow as tf 
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = TFGPT2LMHeadModel.from_pretrained("gpt2", pad_token_id=tokenizer.eos_token_id)
# Out:
# ...
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# ...

# %%
def generate_text(inp):
  input_ids = tokenizer.encode(inp, return_tensors='tf')
  beam_output = model.generate(input_ids, max_length=100, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
  output = tokenizer.decode(beam_output[0], skip_special_tokens=True, clean_up_tokenization_spaces=True)
  return ".".join(output.split(".")[:-1]) +  "."

# %%
output_text = gr.outputs.Textbox()
gr.Interface(generate_text,"textbox", output_text, title="GPT-2",
             description="""OpenAI's GPT-2 (Generative Pre-trained Transformer 2) is a large-scale neural language model that is capable of generating human-like text. It was developed by OpenAI, an artificial intelligence research organization, and is considered to be one of the most advanced text-generation models available.

GPT-2 is a type of deep learning model that has been pre-trained on a large corpus of text data. During this pre-training, the model is exposed to a massive amount of text, allowing it to learn the statistical patterns and structures of natural language. This pre-training enables the model to generate high-quality text in a wide range of styles and on a variety of topics.

OpenAI's GPT-2 model has been used for a variety of natural language processing tasks, such as text classification, translation, and summarization. It has also been used to generate text in a variety of applications, such as chatbots, language translation, and content creation.""").launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
